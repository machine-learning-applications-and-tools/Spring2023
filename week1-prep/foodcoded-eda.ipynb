# %% [markdown]
# ## Exercises
#
# ### 1. Clean up the GPA column in the dataset.
#  - For rows that contain GPA numbers and extra string characters, you need to remove the string character but keep the number value. E.g., `2.1hello` should be transformed into `2.1`.
#  - Remove rows that contain `nan` or empty strings in the 'GPA' column from the dataset.
#  You should have 121 rows of data remaining after this operation.
#
# ### 2. Find out which column most positively correlates to the GPA column. Use 1-2 sentences to explain your finding.

# %%
import pandas as pd
import numpy as np
np.set_printoptions(precision=2, suppress=True)
pd.options.display.float_format = '${:,.2f}'.format

# %% [markdown]
# Read in data in csv format as a Pandas data frame. A __DataFrame__ is a 2-dimensional labeled data structure with columns of potentially different types.

# %%
df = pd.read_csv('foodcoded.csv')

# %%
df.shape
# Out:
# (125, 61)

# %%
df.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430          $nan         $315.00
# 1  3.654       1          1               610         $3.00         $420.00
# 2    3.3       1          1               720         $4.00         $420.00
# 3    3.2       1          1               430         $3.00         $420.00
# 4    3.5       1          1               720         $2.00         $420.00
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          124 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         21
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
df['GPA'].value_counts()
# Out:
# 3.5           13
# 3             11
# 3.7           10
# 3.2           10
# 3.4            9
# 3.3            9
# 3.6            7
# 3.9            7
# 3.8            6
# 2.8            5
# 4              4
# 3.1            3
# 3.83           2
# 2.9            2
# 2.6            2
# 3.292          1
# 3.605          1
# Unknown        1
# Personal       1
# 2.25           1
# 2.71           1
# 3.75           1
# 3.35           1
# 3.63           1
# 3.89           1
# 2.4            1
# 3.73           1
# 3.65           1
# 3.67           1
# 2.2            1
# 3.77           1
# 3.79 bitch     1
# 3.87           1
# 3.904          1
# 3.92           1
# 3.882          1
# 3.68           1
# 3.654          1
# Name: GPA, dtype: int64

# %%
df['GPA'] = df['GPA'].str.replace(r'[^0-9.]', '')
df['GPA'].value_counts()
# Out:
# 3.5      13
# 3        11
# 3.7      10
# 3.2      10
# 3.4       9
# 3.3       9
# 3.6       7
# 3.9       7
# 3.8       6
# 2.8       5
# 4         4
# 3.1       3
# 2.9       2
# 2.6       2
# 3.83      2
#           2
# 3.75      1
# 2.71      1
# 3.63      1
# 2.25      1
# 3.292     1
# 3.605     1
# 3.35      1
# 3.65      1
# 3.89      1
# 2.4       1
# 3.73      1
# 3.67      1
# 2.2       1
# 3.79      1
# 3.77      1
# 3.87      1
# 3.904     1
# 3.92      1
# 3.882     1
# 3.68      1
# 3.654     1
# Name: GPA, dtype: int64

# %%
df.isna().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         21
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %% [markdown]
# replace the empty string to `nan` so they can be remove in the next step

# %%
df['GPA'].replace('', np.nan, inplace=True)

# %%
df.isna().sum()
# Out:
# GPA                  4
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         21
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
df = df.dropna(subset=['GPA'])

# %%
df['GPA'] = df['GPA'].astype('float')

# %%
df.shape
# Out:
# (121, 61)

# %% [markdown]
# Select only the numeric columns

# %%
df_num = df.select_dtypes('number')

# %%
df_num.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food_reasons_coded', 'cook',
#        'comfort_food_reasons_coded.1', 'cuisine', 'diet_current_coded',
#        'drink', 'eating_changes_coded', 'eating_changes_coded1', 'eating_out',
#        'employment', 'ethnic_food', 'exercise', 'father_education',
#        'fav_cuisine_coded', 'fav_food', 'fries', 'fruit_day', 'grade_level',
#        'greek_food', 'healthy_feeling', 'ideal_diet_coded', 'income',
#        'indian_food', 'italian_food', 'life_rewarding', 'marital_status',
#        'mother_education', 'nutritional_check', 'on_off_campus',
#        'parents_cook', 'pay_meal_out', 'persian_food',
#        'self_perception_weight', 'soup', 'sports', 'thai_food',
#        'tortilla_calories', 'turkey_calories', 'veggies_day', 'vitamins',
#        'waffle_calories'],
#       dtype='object')

# %%
corr = df_num.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# ...
